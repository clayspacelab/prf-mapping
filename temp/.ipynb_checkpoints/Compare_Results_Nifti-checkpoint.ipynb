# %%
import os as os
import ctypes
import pickle
import multiprocessing as mp

import tqdm
import numpy as np
from scipy.io import loadmat
from scipy.signal import detrend
import nibabel as nib

import popeye.utilities as utils
from popeye import css
from popeye.visual_stimulus import VisualStimulus, resample_stimulus

# %%
nii = nib.load('/Users/aditya/Documents/GitHub/prf-mapping/sample_data/JC/RF1/JC_RF1_vista/bar_seq_1_surf.nii.gz')
# example of how to load the results
f = open('css_results.pkl', 'rb')
results = pickle.load(f)

# %%
# screen out failed fits
output = [r for r in results if r is not None]

# %%
nifti = utils.recast_estimation_results(output, nii, overloaded=True)

# %%
nifti

# %%
nifti.shape
# Out:
# (128, 128, 128, 7)

# %%
Popeye Header

# %%
header = nifti.header
print(header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 48
# dim             : [  4 128 128 128   7   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.  2.  2.  2.  1.3 1.  1.  1. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 127
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 1.0
# qoffset_x       : 127.49991
# ...

# %%
nii.shape
# Out:
# (128, 128, 128, 201)

# %%
vista_result = nib.load("/Users/aditya/Library/Mobile Documents/com~apple~CloudDocs/Work/Clayspace/deleted/RF_surf-fFit.nii.gz")

# %%
vista_result.shape
# Out:
# (128, 128, 128, 8)

# %%
header = vista_result.header
print(vista_result_header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 48
# dim             : [  4 128 128 128   8   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.  2.  2.  2.  1.3 0.  0.  0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 127
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 1.0
# qoffset_x       : 127.5
# ...

# %%
type(vista_result)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
vista_result_2 = nib.load("/Users/aditya/Library/Mobile Documents/com~apple~CloudDocs/Work/Clayspace/deleted/RF_func-sFit.nii.gz")

# %%
vista_result_2.shape
# Out:
# (128, 128, 128, 8)

# %%
data1 = nifti.get_fdata()
data2 = vista_result.get_fdata()

# %%
mean1 = np.mean(data1)
std1 = np.std(data1)
mean2 = np.mean(data2)
std2 = np.std(data2)

# %%
print(f"Mean of dataset 1: {mean1}, Standard Deviation of dataset 1: {std1}")
print(f"Mean of dataset 2: {mean2}, Standard Deviation of dataset 2: {std2}")
# Out:
# Mean of dataset 1: 59.563089535007975, Standard Deviation of dataset 1: 923.1608732003843
# Mean of dataset 2: 0.2567372832793827, Standard Deviation of dataset 2: 5.22754763813186

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data1[:, :, 97, 6])
plt.title("First Dataset Slice")
plt.colorbar()
plt.show()

# %%
plt.imshow(data2[:, :, 97, 7])
plt.title("Second Dataset Slice")
plt.colorbar()
plt.show()
