# %%
import numpy as np

# %%
num_voxels = 20

# %%
    # fit_x = temp[0]
    # fit_y = temp[1]
    # fit_sigma = temp[2]
    # fit_n =  temp[3]
    # fit_beta = temp[4]
    # fit_baseline = temp[5]

# %%
# Define the bounds for each variable
x_bound = (-12.0, 12.0)
y_bound = (-12.0, 12.0)
s_bound = (1/17.811033313241005, 12.0)
b_bound = (1e-8, None)
n_bound = (1e-1, 4.0)
u_bound = (-12.0,12.0) # Taking Any arbitrary bounds for now

# %%
# Generate random voxel values within the specified bounds using NumPy
x_values = np.random.uniform(x_bound[0], x_bound[1], num_voxels)
y_values = np.random.uniform(y_bound[0], y_bound[1], num_voxels)
sigma_values = np.random.uniform(s_bound[0], s_bound[1], num_voxels)
beta_values = np.random.uniform(b_bound[0], b_bound[1] if b_bound[1] is not None else 1.0, num_voxels)
n_values = np.random.uniform(n_bound[0], n_bound[1], num_voxels)
u_values = np.random.uniform(u_bound[0], u_bound[1], num_voxels)

# %%
voxels = np.column_stack((x_values, y_values, sigma_values, n_values, beta_values, u_values))

# %%
voxels[0][0]
# Out:
# -10.342450437632316

# %%
print(voxels)
# Out:
# [[-10.34245044   5.44363106   7.72903255   3.90702737   0.65106644
#    11.06179125]
#  [ -9.42186446   9.91816591   6.61949322   3.19199014   0.02766048
#     7.90275535]
#  [  2.00111001   0.33898721   3.22667498   3.42508085   0.81725911
#     5.59527159]
#  [ -8.59543292   4.74974662  11.02293147   0.37236681   0.85275036
#     2.61954953]
#  [ -0.12238456 -10.66802106   0.62779403   0.90059141   0.91526299
#    11.41714553]
#  [ -4.68040955  -2.94983118   0.36397026   0.66920264   0.36377403
#    -5.6668718 ]
#  [  9.56064501   9.45608092   8.46754648   2.1419994    0.3584161
#    -3.66147457]
#  [ -0.91786867   5.01951242   4.15853022   0.8748336    0.03419856
#    -2.52507256]
#  [-11.58930962   8.33916021   0.18841518   1.56094042   0.36896551
#     3.48527409]
#  [ -1.34200322 -10.52133108   7.77156664   2.02725905   0.11013191
#     9.18672224]
#  [ -7.30356967  10.92558454   3.1547591    1.23644436   0.02883428
#    10.48794082]
#  [  8.4909861    7.1112597    3.5557515    2.11325753   0.03817244
#    -1.45252868]
#  [ -7.8453301    2.59794362   6.88277364   2.0172677    0.8130979
#     6.07105404]
#  [  5.08667834   2.57771101  11.20733134   1.77385035   0.92666042
#    10.87119777]
#  [  5.43793271  -5.68627284  11.78488921   0.78546166   0.27615441
#     6.1891956 ]
#  [ 11.07948758  -0.22160926   5.07120424   1.52478512   0.45079919
#    -4.75985185]
#  [  6.23887277   5.56467287   2.74219823   2.39883838   0.3480191
#    -2.07162593]
#  [ -9.40973964 -11.66661828   4.30288077   0.48823157   0.84404307
#    -2.33298245]
#  [-11.41551073  -5.84038355   4.15110105   1.49390169   0.20231711
#   -10.44257006]
#  [ -7.82829266  -9.69133747   1.18025575   0.50573419   0.24865625
#    -2.53006028]]

# %%
import ctypes, multiprocessing
import numpy as np
import sharedmem
from popeye import css
import popeye.utilities as utils
from popeye.visual_stimulus import VisualStimulus, simulate_bar_stimulus
from matplotlib import pyplot

# %%
### STIMULUS
## create sweeping bar stimulus
thetas = np.array([-1,0,90,180,270,-1]) # in degrees, -1 is blank
bar = simulate_bar_stimulus(100, 100, 40, 20, thetas, 30, 30, 10)

## create an instance of the Stimulus class
stimulus = VisualStimulus(bar, 50, 25, 0.50, 1.0, ctypes.c_int16)

### MODEL
## initialize the gaussian model
model = css.CompressiveSpatialSummationModel(stimulus, utils.double_gamma_hrf)
model.hrf_delay = 0 #This is additional delay; Note that double_gamma_hrf already has 5 sec delay by default

# %%
### FIT
## define search grids
# these define min and max of the edge of the initial brute-force search.
x_grid = (-10, 10)
y_grid = (-10, 10)
s_grid = (0.25, 12)
n_grid = (.1, 4) #exponent

## define search bounds
# these define the boundaries of the final gradient-descent search.
x_bound = (-12.0, 12.0)
y_bound = (-12.0,12.0)
s_bound = (1/stimulus.ppd, 12.0) #smallest sigma is a pixel
b_bound = (1e-8,None)
u_bound = (None,None)
n_bound = (1e-1, 4.0)

# %%
grids = (x_grid, y_grid, s_grid, n_grid)
bounds = (x_bound, y_bound, s_bound, n_bound, b_bound, u_bound,)

# %%
sigma_values, beta_values, n_values, u_values
# Out:
# (array([ 7.72903255,  6.61949322,  3.22667498, 11.02293147,  0.62779403,
#          0.36397026,  8.46754648,  4.15853022,  0.18841518,  7.77156664,
#          3.1547591 ,  3.5557515 ,  6.88277364, 11.20733134, 11.78488921,
#          5.07120424,  2.74219823,  4.30288077,  4.15110105,  1.18025575]),
#  array([0.65106644, 0.02766048, 0.81725911, 0.85275036, 0.91526299,
#         0.36377403, 0.3584161 , 0.03419856, 0.36896551, 0.11013191,
#         0.02883428, 0.03817244, 0.8130979 , 0.92666042, 0.27615441,
#         0.45079919, 0.3480191 , 0.84404307, 0.20231711, 0.24865625]),
#  array([3.90702737, 3.19199014, 3.42508085, 0.37236681, 0.90059141,
#         0.66920264, 2.1419994 , 0.8748336 , 1.56094042, 2.02725905,
#         1.23644436, 2.11325753, 2.0172677 , 1.77385035, 0.78546166,
#         1.52478512, 2.39883838, 0.48823157, 1.49390169, 0.50573419]),
#  array([ 11.06179125,   7.90275535,   5.59527159,   2.61954953,
#          11.41714553,  -5.6668718 ,  -3.66147457,  -2.52507256,
#           3.48527409,   9.18672224,  10.48794082,  -1.45252868,
#           6.07105404,  10.87119777,   6.1891956 ,  -4.75985185,
#          -2.07162593,  -2.33298245, -10.44257006,  -2.53006028]))

# %%
fitted_data_array = np.empty((num_voxels, 6))

# %%
for voxel_index, voxel in enumerate(voxels):
    x = voxel[0]
    y = voxel[1]
    sigma = voxel[2]
    n = voxel[3]
    beta = voxel[4]
    baseline = voxel[5]
    data = model.generate_prediction(x, y, sigma, n, beta, baseline)
    data += np.random.uniform(-data.max()/10,data.max()/10,len(data))
    fit = css.CompressiveSpatialSummationFit(model, data, grids, bounds, Ns=3, voxel_index=(1,2,3), auto_fit=True,verbose=2)
    temp = fit.estimate
    fit_x = temp[0]
    fit_y = temp[1]
    fit_sigma = temp[2]
    fit_n =  temp[3]
    fit_beta = temp[4]
    fit_baseline = temp[5]
    print("x: ", x, "Fit x: ", fit_x)
    print("y: ", y, "Fit y: ", fit_y)
    print("sigma: ", x, "Fit sigma: ", fit_sigma)
    print("n: ", n, "Fit n: ", fit_n)
    print("beta: ", beta, "Fit beta: ", fit_beta)
    print("baseline: ", baseline, "Fit baseline: ", fit_baseline)
    print()
    fitted_data_array[voxel_index] = fit.estimate
# Out:
# The gridfit solution was [-10.          10.          12.           4.           0.77922002
#   11.01380889], starting gradient descent ...
# VOXEL=(001,002,003)   TIMEMS=1203   RSQ=0.71  EST=[ 2.6066 11.5062  3.9335  3.6884  0.683  11.0138]
# x:  -10.342450437632316 Fit x:  -9.898303638230193
# y:  5.443631063249438 Fit y:  5.866512795738078
# sigma:  -10.342450437632316 Fit sigma:  7.554260541982043
# n:  3.9070273654331054 Fit n:  3.6883537105026463
# beta:  0.651066442963627 Fit beta:  0.6830080464279216
# baseline:  11.061791245602695 Fit baseline:  11.013809533151864
#
# The gridfit solution was [-10.          10.           0.25         4.           0.01357523
#    7.87820497], starting gradient descent ...
# VOXEL=(001,002,003)   TIMEMS=0778   RSQ=0.02  EST=[ 2.2702 14.348   0.3457  4.      0.0159  7.8782]
# x:  -9.421864455068238 Fit x:  -9.236410969432251
# y:  9.91816590800261 Fit y:  10.979681520357328
# sigma:  -9.421864455068238 Fit sigma:  0.6913634730797767
# n:  3.191990141041442 Fit n:  4.0
# beta:  0.02766047942670146 Fit beta:  0.01591653843622863
# baseline:  7.902755350250029 Fit baseline:  7.8782049555991716
#
# The gridfit solution was [0.         0.         0.25       0.1        0.61395203 5.56396406], starting gradient descent ...
# VOXEL=(001,002,003)   TIMEMS=1790   RSQ=0.90  EST=[0.1359 2.1878 1.6596 1.8419 0.7889 5.564 ]
# x:  2.001110011985995 Fit x:  2.167642595730039
# y:  0.3389872062986399 Fit y:  0.29633641264150906
# sigma:  2.001110011985995 Fit sigma:  2.25238260839989
# n:  3.425080851289411 Fit n:  1.8418854998786636
# beta:  0.8172591080063558 Fit beta:  0.7889256185356661
# baseline:  5.5952715918803015 Fit baseline:  5.563964069342915
#
# The gridfit solution was [-10.          10.           6.125        0.1          0.85943055
#    2.60896777], starting gradient descent ...
# VOXEL=(001,002,003)   TIMEMS=1416   RSQ=0.92  EST=[ 2.6728  8.8215 18.0241  0.4433  0.8757  2.609 ]
# x:  -8.595432924550433 Fit x:  -7.869688850110843
# y:  4.749746624858947 Fit y:  3.9858640930436326
# sigma:  -8.595432924550433 Fit sigma:  12.0
# n:  0.3723668110844862 Fit n:  0.44325477515627526
# beta:  0.8527503638593746 Fit beta:  0.8757048878345637
# baseline:  2.6195495306140764 Fit baseline:  2.6089678895935173
#
# The gridfit solution was [  0.         -10.           0.25         4.           0.89201178
#   11.46714412], starting gradient descent ...
# VOXEL=(001,002,003)   TIMEMS=
#           0.36331269,  -5.66080565],
#        [  8.61437162,   8.70315051,  10.35130915,   4.        ,
#           0.35523885,  -3.66102309],
#        [ -2.02496484,   3.58322052,   3.32550298,   3.96355506,
#           0.01758102,  -2.51574483],
#        [ -0.29772738,  12.        ,   7.12556012,   4.        ,
#           0.62780264,   3.55319076],
#        [ -1.68259742,  -7.48588877,   5.98657901,   4.        ,
#           0.11245627,   9.13519752],
#        [ 10.        ,   0.        ,   0.28072487,   2.05      ,
#           0.00000001,  10.480114  ],
#        [  8.86691154,   7.18945736,   4.92451895,   2.76496795,
#           0.04279249,  -1.46178895],
#        [ -7.53969001,   3.00892323,   7.34502379,   2.33227376,
#           0.83455627,   6.06776018],
#        [  4.31653089,   1.53878993,   8.99742143,   1.29093698,
#           0.92506919,  10.8629611 ],
#        [  2.44317186,  -4.63880748,  12.        ,   1.16113293,
#           0.2749786 ,   6.18979923],
#        [ 11.1100187 ,  -0.24058817,   5.30410646,   1.55779115,
#           0.45432604,  -4.77089276],
#        [  6.23889979,   5.56567322,   2.80325745,   2.49504288,
#           0.34798896,  -2.07152384],
#        [ -9.27836261, -11.47916117,   4.37140281,   0.51758899,
#           0.8381114 ,  -2.33011771],
#        [-12.        ,  -6.34113902,   3.82760899,   1.19873991,
#           0.16430636, -10.42053107],
#        [ -7.89242214,  -9.73352281,   1.44614544,   0.65694129,
#           0.2502735 ,  -2.52952501]])

# %%
parameters_names = ['x', 'y', 'sigma', 'n', 'beta', 'baseline']

# Calculate Mean Squared Error for each parameter
mse_per_parameter = np.mean((voxels - fitted_data_array) ** 2, axis=0)

# Print the MSE for each parameter
print("Mean Squared Error for Each Parameter:")
for i, mse in enumerate(mse_per_parameter):
    print(f"{parameters_names[i]}: {mse}")
# Out:
# Mean Squared Error for Each Parameter:
# x: 22.00527748996148
# y: 7.459792525999326
# sigma: 5.413463354853729
# n: 1.3955586628912677
# beta: 0.0036323404843662923
# baseline: 0.0007365318870506116

# %%
def dry_run(num_voxels):
    print("For ", num_voxels)
    x_bound = (-12.0, 12.0)
    y_bound = (-12.0, 12.0)
    s_bound = (1/17.811033313241005, 12.0)
    b_bound = (1e-8, None)
    n_bound = (1e-1, 4.0)
    u_bound = (-12.0,12.0) # Taking Any arbitrary bounds for now
    # Generate random voxel values within the specified bounds using NumPy
    x_values = np.random.uniform(x_bound[0], x_bound[1], num_voxels)
    y_values = np.random.uniform(y_bound[0], y_bound[1], num_voxels)
    sigma_values = np.random.uniform(s_bound[0], s_bound[1], num_voxels)
    beta_values = np.random.uniform(b_bound[0], b_bound[1] if b_bound[1] is not None else 1.0, num_voxels)
    n_values = np.random.uniform(n_bound[0], n_bound[1], num_voxels)
    u_values = np.random.uniform(u_bound[0], u_bound[1], num_voxels)
    voxels = np.column_stack((x_values, y_values, sigma_values, n_values, beta_values, u_values))
    fitted_data_array = np.empty((num_voxels, 6)) 
    for voxel_index, voxel in enumerate(voxels):
        x = voxel[0]
        y = voxel[1]
        sigma = voxel[2]
        n = voxel[3]
        beta = voxel[4]
        baseline = voxel[5]
        data = model.generate_prediction(x, y, sigma, n, beta, baseline)
        data += np.random.uniform(-data.max()/10,data.max()/10,len(data))
        fit = css.CompressiveSpatialSummationFit(model, data, grids, bounds, Ns=3, voxel_index=(1,2,3), auto_fit=True,verbose=2)
        temp = fit.estimate
        fit_x = temp[0]
        fit_y = temp[1]
        fit_sigma = temp[2]
        fit_n =  temp[3]
        fit_beta = temp[4]
        fit_baseline = temp[5]
        print("x: ", x, "Fit x: ", fit_x)
        print("y: ", y, "Fit y: ", fit_y)
        print("sigma: ", x, "Fit sigma: ", fit_sigma)
        print("n: ", n, "Fit n: ", fit_n)
        print("beta: ", beta, "Fit beta: ", fit_beta)
        print("baseline: ", baseline, "Fit baseline: ", fit_baseline)
        print()
        fitted_data_array[voxel_index] = fit.estimate
    parameters_names = ['x', 'y', 'sigma', 'n', 'beta', 'baseline']
    
    # Calculate Mean Squared Error for each parameter
    mse_per_parameter = np.mean((voxels - fitted_data_array) ** 2, axis=0)
    
    # Print the MSE for each parameter
    print("Mean Squared Error for Each Parameter:")
    for i, mse in enumerate(mse_per_parameter):
        print(f"{parameters_names[i]}: {mse}")

# %%
dry_run(10)
# Out:
# For  10
# The gridfit solution was [10.         10.         12.          4.          0.16036776  0.26030569], starting gradient descent ...
# VOXEL=(001,002,003)   TIMEMS=1415   RSQ=0.96  EST=[0.9401 7.4252 2.2351 3.5573 0.1487 0.2603]
# x:  4.316320195586769 Fit x:  4.378605768248953
# y:  6.084753232196789 Fit y:  5.996834941954842
# sigma:  4.316320195586769 Fit sigma:  4.215630612318334
# n:  2.841514758214029 Fit n:  3.557346918503164
# beta:  0.149307099945605 Fit beta:  0.14869744741864124
# baseline:  0.2566125239873003 Fit baseline:  0.2603042530282978
#
# The gridfit solution was [ 10.         -10.           6.125        4.           0.57917999
#  -11.69607551], starting gradient descent ...
# VOXEL=(001,002,003)   TIMEMS=1357   RSQ=0.94  EST=[  5.5344  13.573    2.5033   1.2632   0.5536 -11.6961]
# x:  9.957248094982411 Fit x:  9.942677390827761
# y:  -9.355439498493347 Fit y:  -9.239614734484334
# sigma:  9.957248094982411 Fit sigma:  2.813523772548808
# n:  2.692661282532172 Fit n:  1.2632368827496052
# beta:  0.5584636302656375 Fit beta:  0.5535772011442036
# baseline:  -11.691454514187237 Fit baseline:  -11.696077023171403
#
# The gridfit solution was [10.          0.          6.125       2.05        0.95751413 -1.71680756], starting gradient descent ...
# VOXEL=(001,002,003)   TIMEMS=0981   RSQ=0.99  EST=[ 0.2209  8.9233  3.1573  0.9613  0.9325 -1.7168]
# x:  8.78448627817675 Fit x:  8.70654392976028
# y:  1.9702809539445951 Fit y:  1.955005734431864
# sigma:  8.78448627817675 Fit sigma:  3.0956298823658814
# n:  0.9912317859733923 Fit n:  0.9613212096619876
# beta:  0.9281750799541243 Fit beta:  0.9324890589552349
# baseline:  -1.7052892162947622 Fit baseline:  -1.7168049759473216
#
# The gridfit solution was [0.         0.         0.25       0.1        1.00687923 3.47742837], starting gradient descent ...
# VOXEL=(001,002,003)   TIMEMS=
starting gradient descent ...
# VOXEL=(001,002,003)   TIMEMS=1657   RSQ=0.99  EST=[ 0.8543  9.3612  0.2372  3.9843  0.6967 -9.8147]
# x:  6.174364226164958 Fit x:  6.1479937621522325
# y:  7.0696106547705035 Fit y:  7.059379457804272
# sigma:  6.174364226164958 Fit sigma:  0.47343476008368984
# n:  3.668799834953321 Fit n:  3.9843473044411195
# beta:  0.7015426344628367 Fit beta:  0.6966747610280675
# baseline:  -9.808869362652072 Fit baseline:  -9.814669553742068
#
# Mean Squared Error for Each Parameter:
# x: 2.303195797229152
# y: 1.7232463429289737
# sigma: 6.629956317173831
# n: 0.7445840787300746
# beta: 0.000487435629616424
# baseline: 0.000509168627179592

# %%
# dry_run(100)

# %%
#this is without adding any noise
def dry_run_no_noise(num_voxels):
    print("For ", num_voxels)
    x_bound = (-12.0, 12.0)
    y_bound = (-12.0, 12.0)
    s_bound = (1/17.811033313241005, 12.0)
    b_bound = (1e-8, None)
    n_bound = (1e-1, 4.0)
    u_bound = (-12.0,12.0) # Taking Any arbitrary bounds for now
    # Generate random voxel values within the specified bounds using NumPy
    x_values = np.random.uniform(x_bound[0], x_bound[1], num_voxels)
    y_values = np.random.uniform(y_bound[0], y_bound[1], num_voxels)
    sigma_values = np.random.uniform(s_bound[0], s_bound[1], num_voxels)
    beta_values = np.random.uniform(b_bound[0], b_bound[1] if b_bound[1] is not None else 1.0, num_voxels)
    n_values = np.random.uniform(n_bound[0], n_bound[1], num_voxels)
    u_values = np.random.uniform(u_bound[0], u_bound[1], num_voxels)
    voxels = np.column_stack((x_values, y_values, sigma_values, n_values, beta_values, u_values))
    fitted_data_array = np.empty((num_voxels, 6)) 
    for voxel_index, voxel in enumerate(voxels):
        x = voxel[0]
        y = voxel[1]
        sigma = voxel[2]
        n = voxel[3]
        beta = voxel[4]
        baseline = voxel[5]
        data = model.generate_prediction(x, y, sigma, n, beta, baseline)
        # data += np.random.uniform(-data.max()/10,data.max()/10,len(data))
        fit = css.CompressiveSpatialSummationFit(model, data, grids, bounds, Ns=3, voxel_index=(1,2,3), auto_fit=True,verbose=2)
        temp = fit.estimate
        fit_x = temp[0]
        fit_y = temp[1]
        fit_sigma = temp[2]
        fit_n =  temp[3]
        fit_beta = temp[4]
        fit_baseline = temp[5]
        print("x: ", x, "Fit x: ", fit_x)
        print("y: ", y, "Fit y: ", fit_y)
        print("sigma: ", x, "Fit sigma: ", fit_sigma)
        print("n: ", n, "Fit n: ", fit_n)
        print("beta: ", beta, "Fit beta: ", fit_beta)
        print("baseline: ", baseline, "Fit baseline: ", fit_baseline)
        print()
        fitted_data_array[voxel_index] = fit.estimate
    parameters_names = ['x', 'y', 'sigma', 'n', 'beta', 'baseline']
    
    # Calculate Mean Squared Error for each parameter
    mse_per_parameter = np.mean((voxels - fitted_data_array) ** 2, axis=0)
    
    # Print the MSE for each parameter
    print("Mean Squared Error for Each Parameter:")
    for i, mse in enumerate(mse_per_parameter):
        print(f"{parameters_names[i]}: {mse}")

# %%
dry_run_no_noise(10)
# Out:
# For  10
# The gridfit solution was [ 0.         10.         12.          2.05        0.14616429  4.64707968], starting gradient descent ...
# VOXEL=(001,002,003)   TIMEMS=