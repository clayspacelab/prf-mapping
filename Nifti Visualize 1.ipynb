# %%
import os
import numpy as np

# %%
import scipy.ndimage as ndi

# %%
import nibabel as nib

# %%
import matplotlib.pyplot as plt

# %%
filename = "/Users/aditya/Library/Mobile Documents/com~apple~CloudDocs/Work/Clayspace/sample_data/JC/surfanat_brainmask_hires.nii.gz"

# %%
img2 = nib.load(filename)

# %%
img2.shape #fourth parameter which is the TR is missing from the data
# Out:
# (256, 256, 128)

# %%
type(img2)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
img_data = img2.get_fdata()
sliced_img_data = img_data[119]  # Perform slicing on the image data
plt.imshow(sliced_img_data, cmap='bone')
plt.axis('off')
plt.show()

# %%
plt.imshow(ndi.rotate(sliced_img_data, 90), cmap='bone')
plt.axis('off')
plt.show()

# %%
header = img2.header

# %%
header.get_zooms()
# Out:
# (1.0, 1.0, 2.0)

# %%
print(header['pixdim'][4])
# Out:
# 0.0

# %%
img2.shape
# Out:
# (256, 256, 128)
